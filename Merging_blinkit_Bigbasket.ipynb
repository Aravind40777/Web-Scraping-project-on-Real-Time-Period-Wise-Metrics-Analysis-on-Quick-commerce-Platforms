# %%
import pandas as pd

# %%
path=r"C:\\Users\\veera\\OneDrive\\Desktop\\data_eda\\"
data_frame=[]
for i in range(1,9):
    file=f"{path}bigbasket_{i}_a.csv"
    x=pd.read_csv(file)
    data_frame.append(x)
bigbasket_a=pd.concat(data_frame,ignore_index=True)

# %%
bigbasket_a.columns
# Out:
# Index(['Unnamed: 0', 'name', 'Category', 'mrp', 'selling_price',
#        'offer_percentage', 'delivery_time', 'quantity', 'scrape_date',
#        'scrape_time', 'location', 'Delivery_Charges(Handelling+Delivery)',
#        'Period', 'Surge', 'Climate', 'Surge_charges', 'Late_Night_Charges',
#        'Delivery_Charges(Handelling+Delivery+Late_Night_Charge)'],
#       dtype='object')

# %%
bigbasket_a
# Out:
#      Unnamed: 0                                  name   Category  \
# 0             0                 Heritage Fresh Paneer     Paneer
# 1             1  Heritage Nourish High Protein Paneer     Paneer
# 2             2      Heritage Daily Health Toned Milk       Milk
# 3             3              Heritage Full Cream Milk       Milk
# 4             4                Arokya Full Cream Milk       Milk
# ..          ...                                   ...        ...
# 315          35                 fresho! Nagpur Orange      Fruit
# 316          36          fresho! Mini Orange Imported      Fruit
# 317          37                         fresho! Lemon  Vegetable
# 318          38   fresho! Chilli - Green Long, Medium  Vegetable
# 319          39                  fresho! Bottle Gourd  Vegetable
#
#               mrp selling_price offer_percentage delivery_time  \
# 0    Out of Stock  Out of Stock     Out of Stock  Out of Stock
# ...

# %%
bigbasket_a[["mrp","Period","Delivery_Charges(Handelling+Delivery)"]].head(10)
# Out:
#             mrp Period  Delivery_Charges(Handelling+Delivery)
# 0  Out of Stock  Night                                    0.0
# 1           150  Night                                   26.0
# 2            32  Night                                   26.0
# 3            42  Night                                   26.0
# 4            42  Night                                   26.0
# 5  Out of Stock  Night                                    0.0
# 6            44  Night                                   26.0
# 7            63  Night                                   26.0
# 8            80  Night                                   26.0
# 9  Out of Stock  Night                                    0.0

# %%
bigbasket_a[bigbasket_a["mrp"]!="Out of stock"]
# Out:
#      Unnamed: 0                                  name   Category  \
# 0             0                 Heritage Fresh Paneer     Paneer
# 1             1  Heritage Nourish High Protein Paneer     Paneer
# 2             2      Heritage Daily Health Toned Milk       Milk
# 3             3              Heritage Full Cream Milk       Milk
# 4             4                Arokya Full Cream Milk       Milk
# ..          ...                                   ...        ...
# 315          35                 fresho! Nagpur Orange      Fruit
# 316          36          fresho! Mini Orange Imported      Fruit
# 317          37                         fresho! Lemon  Vegetable
# 318          38   fresho! Chilli - Green Long, Medium  Vegetable
# 319          39                  fresho! Bottle Gourd  Vegetable
#
#               mrp selling_price offer_percentage delivery_time  \
# 0    Out of Stock  Out of Stock     Out of Stock  Out of Stock
# ...

# %%
bigbasket_a[bigbasket_a["Period"]=="Night"].head(20)
# Out:
#     Unnamed: 0                                           name   Category  \
# 0            0                          Heritage Fresh Paneer     Paneer
# 1            1           Heritage Nourish High Protein Paneer     Paneer
# 2            2               Heritage Daily Health Toned Milk       Milk
# 3            3                       Heritage Full Cream Milk       Milk
# 4            4                         Arokya Full Cream Milk       Milk
# 5            5                          Amul Taaza Toned Milk       Milk
# 6            6                             Sids Farm Cow Milk       Milk
# 7            7                      Sids Farm Buffalo A2 Milk       Milk
# 8            8             Amul Gold Homogenised Standardised       Milk
# 9            9                              Amul Buffalo Milk       Milk
# 10          10              Amul Taaza Homogenised Toned Milk       Milk
# 11          11                        Amul Fresh Malai Paneer     Paneer
# ...

# %%
# bigbasket_a["Delivery_Charges(Handelling+Delivery)"]=bigbasket_a["Delivery_Charges(Handelling+Delivery)"]+bigbasket_a["Late_Night_Charges"]

# %%
bigbasket_a.loc[((bigbasket_a["mrp"]!="Out of Stock") & (bigbasket_a["Period"]=="Afternoon")),"Delivery_Charges(Handelling+Delivery)"]=21.0

# %%
bigbasket_a.loc[((bigbasket_a["mrp"]!="Out of Stock") & (bigbasket_a["Period"]=="Night")),"Delivery_Charges(Handelling+Delivery)"]=37.0

# %%
bigbasket_a.loc[((bigbasket_a["mrp"]!="Out of Stock") & (bigbasket_a["Period"]=="Evening")),"Delivery_Charges(Handelling+Delivery)"]=21.0

# %%
bigbasket_a.loc[((bigbasket_a["mrp"]!="Out of Stock") & (bigbasket_a["Period"]=="Morning")),"Delivery_Charges(Handelling+Delivery)"]=26.0

# %%
bigbasket_a[bigbasket_a["Period"]=="Afternoon"]
# Out:
#      Unnamed: 0                                               name   Category  \
# 280           0                              Heritage Fresh Paneer     Paneer
# 281           1               Heritage Nourish High Protein Paneer     Paneer
# 282           2                   Heritage Daily Health Toned Milk       Milk
# 283           3                           Heritage Full Cream Milk       Milk
# 284           4                             Arokya Full Cream Milk       Milk
# 285           5                              Amul Taaza Toned Milk       Milk
# 286           6                                 Sids Farm Cow Milk       Milk
# 287           7                          Sids Farm Buffalo A2 Milk       Milk
# 288           8                 Amul Gold Homogenised Standardised       Milk
# 289           9                                  Amul Buffalo Milk       Milk
# 290          10                  Amul Taaza Homogenised Toned Milk       Milk
# ...

# %%
bigbasket_a["Delivery_Charges(Handelling+Delivery)"].isna().sum()
# Out:
# np.int64(0)

# %%
bigbasket_a["Delivery_Charges(Handelling+Delivery)"]
# Out:
# 0       0.0
# 1      26.0
# 2      26.0
# 3      26.0
# 4      26.0
#        ...
# 315    21.0
# 316    21.0
# 317    21.0
# 318    21.0
# 319    21.0
# Name: Delivery_Charges(Handelling+Delivery), Length: 320, dtype: float64

# %%
path=r"C:\\Users\\veera\\OneDrive\\Desktop\\data_eda\\"
data_frame=[]
for i in range(1,9):
    file=f"{path}bigbasket_{i}_su.csv"
    x=pd.read_csv(file)
    data_frame.append(x)
bigbasket_su=(pd.concat(data_frame,ignore_index=True))

# %%
bigbasket_su[bigbasket_su["Period"]=="Night"]["Delivery_Charges(Handelling+Delivery)"].unique()
# Out:
# array([32., nan])

# %%
bigbasket_s.loc[((bigbasket_s["mrp"]!="Out of Stock") & (bigbasket_s["Period"]=="Morning")),"Delivery_Charges(Handelling+Delivery)"]=21.0

# %%
bigbasket_s.loc[((bigbasket_s["mrp"]!="Out of Stock") & (bigbasket_s["Period"]=="Afternoon")),"Delivery_Charges(Handelling+Delivery)"]=21.0

# %%
bigbasket_s.loc[((bigbasket_s["mrp"]!="Out of Stock") & (bigbasket_s["Period"]=="Evening")),"Delivery_Charges(Handelling+Delivery)"]=21.0

# %%
bigbasket_s.loc[((bigbasket_s["mrp"]!="Out of Stock") & (bigbasket_s["Period"]=="Night")),"Delivery_Charges(Handelling+Delivery)"]=35.0

# %%
bigbasket_s["Delivery_Charges(Handelling+Delivery)"].fillna(0,inplace=True)
# Out:
# C:\Users\veera\AppData\Local\Temp\ipykernel_42572\2310741765.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   bigbasket_s["Delivery_Charges(Handelling+Delivery)"].fillna(0,inplace=True)

# %%
bigbasket_s["Delivery_Charges(Handelling+Delivery)"].isna().sum()
# Out:
# np.int64(0)

# %%
bigbasket_su=bigbasket_su.drop(columns="Unnamed: 0")

# %%
path=r"C:\\Users\\veera\\OneDrive\\Desktop\\data_eda\\"
data_frame=[]
for i in range(1,9):
    file=f"{path}bigbasket_{i}_s.csv"
    x=pd.read_csv(file)
    data_frame.append(x)
bigbasket_s=(pd.concat(data_frame,ignore_index=True))

# %%
bigbasket_s
# Out:
#      Unnamed: 0                                  name   Category  \
# 0             0                 Heritage Fresh Paneer     Paneer
# 1             1  Heritage Nourish High Protein Paneer     Paneer
# 2             2      Heritage Daily Health Toned Milk       Milk
# 3             3              Heritage Full Cream Milk       Milk
# 4             4                Arokya Full Cream Milk       Milk
# ..          ...                                   ...        ...
# 315          35                 fresho! Nagpur Orange      Fruit
# 316          36          fresho! Mini Orange Imported      Fruit
# 317          37                         fresho! Lemon  Vegetable
# 318          38   fresho! Chilli - Green Long, Medium  Vegetable
# 319          39                  fresho! Bottle Gourd  Vegetable
#
#               mrp selling_price offer_percentage delivery_time  \
# 0             115           101          12% OFF       11 MINS
# ...

# %%
bigbasket_su.loc[((bigbasket_su["mrp"]!="Out of Stock") & (bigbasket_su["Period"]=="Morning")),"Delivery_Charges(Handelling+Delivery)"]=21.0

# %%
blinkit_s[(blinkit_s["mrp"]!="Out of Stock")& (blinkit_s["Delivery_Charges(Handelling+Delivery)"].isna())]=27

# %%
bigbasket_su.loc[((bigbasket_su["mrp"]!="Out of Stock") & (bigbasket_su["Period"]=="Afternoon")),"Delivery_Charges(Handelling+Delivery)"]=21.0

# %%
bigbasket_su.loc[((bigbasket_su["mrp"]!="Out of Stock") & (bigbasket_su["Period"]=="Evening")),"Delivery_Charges(Handelling+Delivery)"]=21.0

# %%
bigbasket_su.loc[((bigbasket_su["mrp"]!="Out of Stock") & (bigbasket_su["Period"]=="Night")),"Delivery_Charges(Handelling+Delivery)"]=32.0

# %%
bigbasket_s[bigbasket_s["Period"]=="Evening"]["Delivery_Charges(Handelling+Delivery)"].unique()
# Out:
# array([nan])

# %%
path=r"C:\\Users\\veera\\OneDrive\\Desktop\\data_eda\\"
data_frame=[]
for i in range(1,10):
    file=f"{path}blinkit_{i}_a.csv"
    x=pd.read_csv(file)
    data_frame.append(x)
blinkit_a=(pd.concat(data_frame,ignore_index=True))

# %%
blinkit_a
# Out:
#      Unnamed: 0                                   name   Category    mrp  \
# 0             0                  Heritage Fresh Paneer     Paneer  115.0
# 1             1  Heritage Nourish+ High Protein Paneer     Paneer  150.0
# 2             2       Heritage Daily Health Toned Milk       Milk     32
# 3             3               Heritage Full Cream Milk       Milk     42
# 4             4                 Arokya Full Cream Milk       Milk     42
# ..          ...                                    ...        ...    ...
# 355          35                        Nagpur - Orange      Fruit   76.0
# 356          36                 Mini Orange (Imported)      Fruit   65.0
# 357          37                       Lemon (Nimakaya)  Vegetable   45.0
# 358          38              Green Chilli (Mirapakaya)  Vegetable   12.0
# 359          39                Bottle Gourd (Sorakaya)  Vegetable   31.0
#
#     selling_price offer_percentage delivery_time quantity scrape_date  \
# ...

# %%
blinkit_a[blinkit_a["mrp"]!="Out of Stock"]["Delivery_Charges(Handelling+Delivery)"].unique()
# Out:
# array([36, 35])

# %%
blinkit_a[blinkit_a["Delivery_Charges(Handelling+Delivery)"]==36]["Period"].unique()
# Out:
# array(['Afternoon', 'Evening', 'Night', 'Morning'], dtype=object)

# %%
blinkit_a["Delivery_Charges(Handelling+Delivery)"].isna().sum()
# Out:
# np.int64(0)

# %%
path=r"C:\\Users\\veera\\OneDrive\\Desktop\\data_eda\\"
data_frame=[]
for i in range(1,11):
    file=f"{path}blinkit_{i}_su.csv"
    x=pd.read_csv(file)
    data_frame.append(x)
blinkit_su=(pd.concat(data_frame,ignore_index=True))

# %%
blinkit_su
# Out:
#      Unnamed: 0                                   name   Category  \
# 0             0                  Heritage Fresh Paneer     Paneer
# 1             1  Heritage Nourish+ High Protein Paneer     Paneer
# 2             2       Heritage Daily Health Toned Milk       Milk
# 3             3               Heritage Full Cream Milk       Milk
# 4             4                 Arokya Full Cream Milk       Milk
# ..          ...                                    ...        ...
# 395          35                        Nagpur - Orange      Fruit
# 396          36                 Mini Orange (Imported)      Fruit
# 397          37                       Lemon (Nimakaya)  Vegetable
# 398          38              Green Chilli (Mirapakaya)  Vegetable
# 399          39                Bottle Gourd (Sorakaya)  Vegetable
#
#               mrp selling_price offer_percentage delivery_time      quantity  \
# 0           115.0           101          12% OFF        8 MINS         200 g
# ...

# %%
blinkit_su["Delivery_Charges(Handelling+Delivery)"].isna().sum()
# Out:
# np.int64(0)

# %%
path=r"C:\\Users\\veera\\OneDrive\\Desktop\\data_eda\\"
data_frame=[]
for i in range(1,11):
    file=f"{path}blinkit_{i}_s.csv"
    x=pd.read_csv(file)
    data_frame.append(x)
blinkit_s=(pd.concat(data_frame,ignore_index=True))

# %%
blinkit_s[blinkit_s["Period"]=="Night"]
# Out:
#     Unnamed: 0                                   name   Category    mrp  \
# 80           0                  Heritage Fresh Paneer     Paneer    115
# 81           1  Heritage Nourish+ High Protein Paneer     Paneer    150
# 82           2       Heritage Daily Health Toned Milk       Milk     33
# 83           3               Heritage Full Cream Milk       Milk     42
# 84           4                 Arokya Full Cream Milk       Milk     42
# ..         ...                                    ...        ...    ...
# 355         35                        Nagpur - Orange      Fruit   70.0
# 356         36                 Mini Orange (Imported)      Fruit  112.0
# 357         37                       Lemon (Nimakaya)  Vegetable   43.0
# 358         38              Green Chilli (Mirapakaya)  Vegetable   13.0
# 359         39                Bottle Gourd (Sorakaya)  Vegetable   32.0
#
#     selling_price offer_percentage delivery_time quantity scrape_date  \
# ...

# %%
blinkit_s["Delivery_Charges(Handelling+Delivery)"].isna().sum()
# Out:
# np.int64(40)

# %%
blinkit_s[blinkit_s["mrp"]!="Out of Stock"]["Delivery_Charges(Handelling+Delivery)"].unique()
# Out:
# array([27., 29., 25., 21., nan])

# %%
blinkit_s[blinkit_s["Delivery_Charges(Handelling+Delivery)"].isna()]
# Out:
#     Unnamed: 0                                               name   Category  \
# 240          0                              Heritage Fresh Paneer     Paneer
# 241          1              Heritage Nourish+ High Protein Paneer     Paneer
# 242          2                   Heritage Daily Health Toned Milk       Milk
# 243          3                           Heritage Full Cream Milk       Milk
# 244          4                             Arokya Full Cream Milk       Milk
# 245          5                          Sids Farm Buffalo A2 Milk       Milk
# 246          6                              Amul Taaza Toned Milk       Milk
# 247          7                                 Sids Farm Cow Milk       Milk
# 248          8                 Amul Gold Homogenised Standardised      Other
# 249          9                                  Amul Buffalo Milk       Milk
# 250         10                  Amul Taaza Homogenised Toned Milk       Milk
# ...

# %%
blinkit_s.loc[(blinkit_s["mrp"]!="Out of Stock")& (blinkit_s["Delivery_Charges(Handelling+Delivery)"].isna()),"Delivery_Charges(Handelling+Delivery)"]=27

# %%
blinkit_s[blinkit_s["mrp"]!="Out of Stock"]["Delivery_Charges(Handelling+Delivery)"].unique()
# Out:
# array([27., 29., 25., 21.])

# %%
blinkit_s[blinkit_s["mrp"]=="Out of Stock"]
# Out:
#     Unnamed: 0                                               name   Category  \
# 0            0                              Heritage Fresh Paneer     Paneer
# 7            7                                 Sids Farm Cow Milk       Milk
# 12          12           FreshtoHome Chicken - Skinless Curry Cut    Chicken
# 14          14  Super Cool Frozen Skinless Chicken Drumstickso...    Chicken
# 15          15                Organically Grown Onion (Ulligadda)  Vegetable
# 17          17                              Desi Tomato (Tamatar)  Vegetable
# 18          18                            Hybrid Tomato (Tamatar)  Vegetable
# 20          20                           Premier Mutton Curry Cut       Meat
# 21          21                             Potato-(Bangala Dumpa)  Vegetable
# 22          22                          Oraganically Grown Potato  Vegetable
# 24          24                           Oragincally Grown Carrot  Vegetable
# ...

# %%
blinkit_s[blinkit_s["mrp"]=="Out of Stock"].isna().sum()
# Out:
# Unnamed: 0                                0
# name                                      0
# Category                                  0
# mrp                                       0
# selling_price                             0
# offer_percentage                          0
# delivery_time                             0
# quantity                                  0
# scrape_date                               0
# scrape_time                               0
# location                                  0
# Delivery_Charges(Handelling+Delivery)     3
# Period                                    3
# Surge                                    27
# Climate                                   3
# Surge_charges                             3
# dtype: int64

# %%
blinkit_s.loc[(blinkit_s["mrp"]=="Out of Stock")&(blinkit_s["Delivery_Charges(Handelling+Delivery)"].isna()),"Delivery_Charges(Handelling+Delivery)"]=0

# %%
blinkit_s[blinkit_s["mrp"]=="Out of Stock"].isna().sum()
# Out:
# Unnamed: 0                                0
# name                                      0
# Category                                  0
# mrp                                       0
# selling_price                             0
# offer_percentage                          0
# delivery_time                             0
# quantity                                  0
# scrape_date                               0
# scrape_time                               0
# location                                  0
# Delivery_Charges(Handelling+Delivery)     0
# Period                                    3
# Surge                                    27
# Climate                                   3
# Surge_charges                             3
# dtype: int64

# %%
bigbasket_main=pd.concat([bigbasket_a,bigbasket_su,bigbasket_s],ignore_index=True)

# %%
bigbasket_main
# Out:
#      Unnamed: 0                                  name   Category  \
# 0             0                 Heritage Fresh Paneer     Paneer
# 1             1  Heritage Nourish High Protein Paneer     Paneer
# 2             2      Heritage Daily Health Toned Milk       Milk
# 3             3              Heritage Full Cream Milk       Milk
# 4             4                Arokya Full Cream Milk       Milk
# ..          ...                                   ...        ...
# 955          35                 fresho! Nagpur Orange      Fruit
# 956          36          fresho! Mini Orange Imported      Fruit
# 957          37                         fresho! Lemon  Vegetable
# 958          38   fresho! Chilli - Green Long, Medium  Vegetable
# 959          39                  fresho! Bottle Gourd  Vegetable
#
#               mrp selling_price offer_percentage delivery_time  \
# 0    Out of Stock  Out of Stock     Out of Stock  Out of Stock
# ...

# %%
bigbasket_main.duplicated().sum()
# Out:
# np.int64(0)

# %%
bigbasket_main[bigbasket_main["mrp"]!="Out of Stock"]["Delivery_Charges(Handelling+Delivery)"].unique()
# Out:
# array([37., 26., 21., 32., 35.])

# %%
bigbasket_main["scrape_date"].unique()
# Out:
# array(['03-03-2026', '04-03-2026', '05-03-2026', '06-03-2026',
#        '2026-03-06', '03/03/2026', '2026-03-04', '2026-03-05'],
#       dtype=object)

# %%
bigbasket_main.to_csv("bigbasket_main.csv",index=False)

# %%
bigbasket_s
# Out:
#      Unnamed: 0                                  name   Category  \
# 0             0                 Heritage Fresh Paneer     Paneer
# 1             1  Heritage Nourish High Protein Paneer     Paneer
# 2             2      Heritage Daily Health Toned Milk       Milk
# 3             3              Heritage Full Cream Milk       Milk
# 4             4                Arokya Full Cream Milk       Milk
# ..          ...                                   ...        ...
# 315          35                 fresho! Nagpur Orange      Fruit
# 316          36          fresho! Mini Orange Imported      Fruit
# 317          37                         fresho! Lemon  Vegetable
# 318          38   fresho! Chilli - Green Long, Medium  Vegetable
# 319          39                  fresho! Bottle Gourd  Vegetable
#
#               mrp selling_price offer_percentage delivery_time  \
# 0             114           102          11% OFF       20 MINS
# ...

# %%
blinkit_main=pd.concat([blinkit_a,blinkit_su,blinkit_s],ignore_index=True)

# %%
blinkit_main
# Out:
#      Unnamed: 0                                   name   Category    mrp  \
# 0             0                  Heritage Fresh Paneer     Paneer  115.0
# 1             1  Heritage Nourish+ High Protein Paneer     Paneer  150.0
# 2             2       Heritage Daily Health Toned Milk       Milk     32
# 3             3               Heritage Full Cream Milk       Milk     42
# 4             4                 Arokya Full Cream Milk       Milk     42
# ...         ...                                    ...        ...    ...
# 1155         35                        Nagpur - Orange      Fruit   67.0
# 1156         36                 Mini Orange (Imported)      Fruit   71.0
# 1157         37                       Lemon (Nimakaya)  Vegetable   45.0
# 1158         38              Green Chilli (Mirapakaya)  Vegetable   13.0
# 1159         39                Bottle Gourd (Sorakaya)  Vegetable   31.0
#
#      selling_price offer_percentage delivery_time quantity scrape_date  \
# ...

# %%
blinkit_main.duplicated().sum()
# Out:
# np.int64(1)

# %%
blinkit_main[blinkit_main.duplicated()]
# Out:
#     Unnamed: 0                      name Category  mrp selling_price  \
# 901         20  Premier Mutton Curry Cut     Meat  799           485
#
#     offer_percentage delivery_time quantity scrape_date scrape_time  \
# 901          39% OFF       13 MINS    480 g  04-03-2026    08:06:35
#
#        location  Delivery_Charges(Handelling+Delivery)   Period  Surge  \
# 901  Beeramguda                                   27.0  Morning    NaN
#
#     Climate Surge_charges
# 901   Clear            No

# %%
bigbasket_main[bigbasket_main["mrp"]!="Out of Stock"]["Delivery_Charges(Handelling+Delivery)"].unique()
# Out:
# array([37., 26., 21., 32., 35.])

# %%
blinkit_main.iloc[900]
# Out:
# Unnamed: 0                                                     20
# name                                     Premier Mutton Curry Cut
# Category                                                     Meat
# mrp                                                           799
# selling_price                                                 485
# offer_percentage                                          39% OFF
# delivery_time                                             13 MINS
# quantity                                                    480 g
# scrape_date                                            04-03-2026
# scrape_time                                              08:06:35
# location                                               Beeramguda
# Delivery_Charges(Handelling+Delivery)                        27.0
# Period                                                    Morning
# Surge                                                         NaN
# ...

# %%
blinkit_main.iloc[902]
# Out:
# Unnamed: 0                                                      22
# name                                     Oraganically Grown Potato
# Category                                                 Vegetable
# mrp                                                             40
# selling_price                                                   35
# offer_percentage                                           12% OFF
# delivery_time                                              17 MINS
# quantity                                                    250 g
# scrape_date                                             04-03-2026
# scrape_time                                               08:07:04
# location                                                Beeramguda
# Delivery_Charges(Handelling+Delivery)                         27.0
# Period                                                     Morning
# Surge                                                          NaN
# ...

# %%
blinkit_main.to_csv("blinkit_main.csv",index=False)
